# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from matplotlib.ticker import FuncFormatter


response = requests.get('https://api.covid19api.com/dayone/country/singapore')
data = pd.read_json(response.text)
data.head()
# Out:
#                                      ID    Country CountryCode Province City  \
# 0  f1471591-909d-4c12-9e8b-26ce43fa3b4e  Singapore          SG
# 1  ad7bf6e4-27b0-46e9-bdc5-998458be7e6c  Singapore          SG
# 2  25bb999d-2443-4505-925d-27f21af143f6  Singapore          SG
# 3  297dd8d4-5417-4922-9ac9-a93b9902d4c8  Singapore          SG
# 4  bee2a95e-2cf6-46e5-b2a5-9f4b4cca9613  Singapore          SG
#
#   CityCode   Lat     Lon  Confirmed  Deaths  Recovered  Active  \
# 0           1.35  103.82          1       0          0       1
# 1           1.35  103.82          3       0          0       3
# 2           1.35  103.82          3       0          0       3
# 3           1.35  103.82          4       0          0       4
# 4           1.35  103.82          5       0          0       5
#
#                        Date
# 0 2020-01-23 00:00:00+00:00
# 1 2020-01-24 00:00:00+00:00
# 2 2020-01-25 00:00:00+00:00
# 3 2020-01-26 00:00:00+00:00
# 4 2020-01-27 00:00:00+00:00

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data
# Out:
#                                                              ID    Country  \
# Date
# 2020-01-23 00:00:00+00:00  f1471591-909d-4c12-9e8b-26ce43fa3b4e  Singapore
# 2020-01-24 00:00:00+00:00  ad7bf6e4-27b0-46e9-bdc5-998458be7e6c  Singapore
# 2020-01-25 00:00:00+00:00  25bb999d-2443-4505-925d-27f21af143f6  Singapore
# 2020-01-26 00:00:00+00:00  297dd8d4-5417-4922-9ac9-a93b9902d4c8  Singapore
# 2020-01-27 00:00:00+00:00  bee2a95e-2cf6-46e5-b2a5-9f4b4cca9613  Singapore
# ...                                                         ...        ...
# 2023-03-05 00:00:00+00:00  afa4564d-8daa-4d0e-9567-8332280e01ca  Singapore
# 2023-03-06 00:00:00+00:00  78a3f989-8f0b-4986-b3b6-03ebb81eb49d  Singapore
# 2023-03-07 00:00:00+00:00  836f094f-6fca-452a-89cd-5f8d69f99d51  Singapore
# 2023-03-08 00:00:00+00:00  7664bd00-ea55-4f33-89e8-75c64998698f  Singapore
# 2023-03-09 00:00:00+00:00  33752c29-2624-4eb9-9391-a5c860a98aef  Singapore
#
#                           CountryCode Province City CityCode   Lat     Lon  \
# Date
# 2020-01-23 00:00:00+00:00          SG                         1.35  103.82
# 2020-01-24 00:00:00+00:00          SG                         1.35  103.82
# 2020-01-25 00:00:00+00:00          SG                         1.35  103.82
# 2020-01-26 00:00:00+00:00          SG                         1.35  103.82
# 2020-01-27 00:00:00+00:00          SG                         1.35  103.82
# ...                               ...      ...  ...      ...   ...     ...
# 2023-03-05 00:00:00+00:00          SG                         1.35  103.82
# 2023-03-06 00:00:00+00:00          SG                         1.35  103.82
# 2023-03-07 00:00:00+00:00          SG                         1.35  103.82
# 2023-03-08 00:00:00+00:00          SG                         1.35  103.82
# 2023-03-09 00:00:00+00:00          SG                         1.35  103.82
#
#                            Confirmed  Deaths  Recovered   Active
# Date
# 2020-01-23 00:00:00+00:00          1       0          0        1
# 2020-01-24 00:00:00+00:00          3       0          0        3
# 2020-01-25 00:00:00+00:00          3       0          0        3
# 2020-01-26 00:00:00+00:00          4       0          0        4
# 2020-01-27 00:00:00+00:00          5       0          0        5
# ...                              ...     ...        ...      ...
# 2023-03-05 00:00:00+00:00    2230868    1722          0  2229146
# 2023-03-06 00:00:00+00:00    2230868    1722          0  2229146
# 2023-03-07 00:00:00+00:00    2230868    1722          0  2229146
# 2023-03-08 00:00:00+00:00    2235294    1722          0  2233572
# 2023-03-09 00:00:00+00:00    2235294    1722          0  2233572
#
# [1142 rows x 12 columns]

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data['Confirmed'])

plt.title('Confirmed COVID-19 Cases in Singapore Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Confirmed Cases')
plt.xticks(rotation=45)
plt.show()
